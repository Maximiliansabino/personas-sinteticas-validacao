# %% [markdown]
# # Análise Exploratória Inicial
#
# ## Geração de Personas Sintéticas para Domínios com Restrição de Dados Reais
#
# Este notebook contém a análise exploratória inicial do projeto, incluindo:
# 1. Validação das fichas de persona
# 2. Estatísticas do corpus sintético
# 3. Visualizações preliminares (wordclouds, distribuições)
#
# ---

# %%
import json
import os
import sys
sys.path.append('../src')

from persona_validator import validate_all
from preprocessing import load_conversations, preprocess_text

# %% [markdown]
# ## 1. Validação das Fichas de Persona

# %%
results = validate_all('../personas')
for name, result in results.items():
    status = '✓' if result.get('valid') else '✗'
    print(f"{status} {name}")
    if not result.get('valid'):
        for err in result.get('errors', []):
            print(f"  → {err}")

# %% [markdown]
# ## 2. Estatísticas do Corpus Sintético
#
# *(A ser preenchido após geração das conversas)*

# %%
# TODO: carregar conversas sintéticas e calcular estatísticas
# - Número de conversas por tipo (predatória/neutra)
# - Número de mensagens por conversa
# - Comprimento médio das mensagens
# - Distribuição de autores
print('Aguardando geração do corpus sintético...')

# %% [markdown]
# ## 3. Visualizações
#
# *(A ser preenchido após geração das conversas)*

# %%
# TODO: wordclouds, distribuições de comprimento, etc.
print('Aguardando geração do corpus sintético...')
